# %%
import pandas as pd

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/AdamLiscia/Classifying-Diabetes-with-NHANES/master/0002-Noise-Removed.csv')

# %%
df1
# Out:
#       Target   Age  Sex_Female  Weight (kg)  Standing Height (cm)   BMI  \
# 0        0.0  62.0           0         94.8                 184.5  27.8
# 1        1.0  53.0           0         90.4                 171.4  30.8
# 2        0.0  78.0           0         83.4                 170.1  28.8
# 3        0.0  56.0           1        109.8                 160.9  42.4
# 4        1.0  42.0           1         55.2                 164.9  20.3
# 5        1.0  72.0           1         64.4                 150.0  28.6
# 6        1.0  22.0           0         76.6                 165.4  28.0
# 7        1.0  32.0           1         64.5                 151.3  28.2
# 8        0.0  56.0           0        108.3                 179.4  33.6
# 9        0.0  46.0           0         86.2                 176.7  27.6
# 10       1.0  45.0           0         76.2                 177.8  24.1
# 11       1.0  30.0           1         71.2                 163.6  26.6
# ...

# %%
df_master = pd.read_csv('https://raw.githubusercontent.com/AdamLiscia/Classifying-Diabetes-with-NHANES/master/Master.csv')

# %%
df_master.columns
# Out:
# (5266, 235)

# %%
df_master_rmn = pd.read_csv('https://raw.githubusercontent.com/AdamLiscia/Classifying-Diabetes-with-NHANES/Removed-Noise/Master.csv')

# %%
df_master_rmn
# Out:
#       Unnamed: 0  Target   Age  Sex_Female  Weight (kg)  Standing Height (cm)  \
# 0              0     1.0  62.0           0         94.8                 184.5
# 1              1     3.0  53.0           0         90.4                 171.4
# 2              2     1.0  78.0           0         83.4                 170.1
# 3              3     2.0  56.0           1        109.8                 160.9
# 4              4     3.0  42.0           1         55.2                 164.9
# 5              5     3.0  72.0           1         64.4                 150.0
# 6              6     3.0  22.0           0         76.6                 165.4
# 7              7     3.0  32.0           1         64.5                 151.3
# 8              9     1.0  56.0           0        108.3                 179.4
# 9             10     2.0  46.0           0         86.2                 176.7
# 10            11     3.0  45.0           0         76.2                 177.8
# ...

# %%
df_test = pd.read_sas(filepath_or_buffer='testing_ideas/DEMO_I.XPT')

# %%
df_test.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  83732.0       9.0       2.0       1.0      62.0       NaN       3.0
# 1  83733.0       9.0       2.0       1.0      53.0       NaN       3.0
# 2  83734.0       9.0       2.0       1.0      78.0       NaN       3.0
# 3  83735.0       9.0       2.0       2.0      56.0       NaN       3.0
# 4  83736.0       9.0       2.0       2.0      42.0       NaN       4.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0       3.0       1.0       NaN    ...          5.0       1.0       3.0
# 1       3.0       1.0       NaN    ...          3.0       3.0       NaN
# 2       3.0       2.0       NaN    ...          3.0       1.0       3.0
# 3       3.0       2.0       NaN    ...          5.0       6.0       NaN
# 4       4.0       2.0       NaN    ...          4.0       3.0       NaN
#
#         WTINT2YR       WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# ...

# %%
# !ls
# Out:
# Mod_5_Project.md    project-ideas.ipynb testing_ideas
